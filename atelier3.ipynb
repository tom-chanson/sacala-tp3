// %% [markdown]
// # TP2

// %%
case class Employee(
  employeeId: Int,
  lastName: String,
  firstName: String,
  title: String,
  reportsTo: Int
)

case class MediaType(
  mediaTypeId: Int,
  name: String
)

case class Genre(
  genreId: Int,
  name: String
)

case class Track(
  trackId: Int,
  name: String,
  mediaType: Int,
  genre: Int
)

case class InvoiceItem(
  invoiceLineId: Int,
  invoiceId: Int,
  trackId: Int,
  unitPrice: BigDecimal,
  quantity: Int
  )

case class Invoice(
  invoiceId: Int,
  items: List[Int]
)

val employees = Array(
  Employee(1, "Adams", "Andrew", "General Manager", 0),
  Employee(2, "Edwards", "Nancy", "Sales Manager", 1),
  Employee(3, "Peacock", "Jane", "Sales Support Agent", 2),
  Employee(4, "Park", "Margaret", "Sales Support Agent", 2),
  Employee(5, "Johnson", "Steve", "Sales Support Agent", 2),
  Employee(6, "Mitchell", "Michael", "IT Manager", 1),
  Employee(7, "King", "Robert", "IT Staff", 6),
  Employee(8, "Callahan", "Laura", "IT Staff", 6)
)

val mediaTypes = Array(
  MediaType(1, "MPEG audio file"),
  MediaType(2, "Protected AAC audio file"),
  MediaType(3, "Protected MPEG-4 video file"),
  MediaType(4, "Purchased AAC audio file"),
  MediaType(5, "AAC audio file")
)

val genres = Array(
  Genre(1, "Rock"),
  Genre(2, "Jazz"),
  Genre(3, "Metal"),
  Genre(4, "Alternative & Punk"),
  Genre(5, "Rock And Roll"),
  Genre(6, "Blues"),
  Genre(7, "Latin"),
  Genre(8, "Reggae"),
  Genre(9, "Pop"),
  Genre(10, "Soundtrack"),
  Genre(11, "Bossa Nova"),
  Genre(12, "Easy Listening"),
  Genre(13, "Heavy Metal"),
  Genre(14, "R&B/Soul"),
  Genre(15, "Electronica/Dance"),
  Genre(16, "World"),
  Genre(17, "Hip Hop/Rap"),
  Genre(18, "Science Fiction"),
  Genre(19, "TV Shows"),
  Genre(20, "Sci Fi & Fantasy"),
  Genre(21, "Drama"),
  Genre(22, "Comedy"),
  Genre(23, "Alternative"),
  Genre(24, "Classical"),
  Genre(25, "Opera")
)

val adjectives = Array("Cosmic", "Electric", "Velvet", "Mystic", "Atomic", "Phantom", "Silent", "Savage", "Eternal", "Digital", "Lost", "Sacred", "Wild", "Urban", "Golden", "Crystal", "Liquid", "Toxic", "Neon", "Crimson", "Stellar", "Raging", "Arctic", "Sonic", "Primal", "Midnight", "Screaming", "Infinite", "Royal", "Lunar")
val nouns = Array("Echo", "Giants", "Wolves", "Horizon", "Empire", "Void", "Thunder", "Dragons", "Saints", "Kings", "Ghosts", "Ravens", "Pirates", "Heroes", "Rebels", "Demons", "Machines", "Angels", "Knights", "Lions", "Shadows", "Zombies", "Wizards", "Killers", "Titans", "Outlaws", "Rebels", "Prophets", "Bandits", "Warriors")
val complements = Array("of Doom", "in Chains", "from Mars", "of the North", "of Death", "in Disguise", "of the Night", "from Hell", "of Tomorrow", "in Flames", "of the Deep", "from Beyond", "of Destruction", "in Shadow", "from the Sky", "of the Abyss", "in Exile", "from the East", "of Eternity", "from the Desert", "of the Underground")

object Track {
  def generateTrack(trackId: Int): Track = {
    val genre = genres(Random.nextInt(genres.length)).genreId
    val mediaType = mediaTypes(Random.nextInt(mediaTypes.length)).mediaTypeId
    val name = s"${adjectives(Random.nextInt(adjectives.length))} ${nouns(Random.nextInt(nouns.length))} ${complements(Random.nextInt(complements.length))}"
    Track(trackId, name, mediaType, genre)
  }
}

import scala.util.Random

object Invoice {
  def generateInvoice(invoiceId: Int, availableTracks: Array[Track]): Invoice = {
    val itemCount = Random.nextInt(5) + 1
    val selectedTracks = Random.shuffle(availableTracks.toList).take(itemCount)

    val items = selectedTracks.zipWithIndex.map { case (track, idx) =>
      val quantity = if (Random.nextDouble() < 0.8) 1 else Random.nextInt(3) + 1
      val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
      InvoiceItem(
        invoiceLineId = invoiceId * 10 + idx + 1,
        invoiceId = invoiceId,
        trackId = track.trackId,
        unitPrice = unitPrice,
        quantity = quantity
      )
    }

    Invoice(invoiceId, items.map(_.invoiceLineId))
  }
}

val tracks = (1 to 200).map(Track.generateTrack).toArray
val invoices = (1 to 2000).map(id => Invoice.generateInvoice(id, tracks)).toArray

tracks.foreach { track =>
  println(f"ID: ${track.trackId}%3d | Name: ${track.name}%-45s | MediaType ID: ${track.mediaType}%2d | Genre ID: ${track.genre}%2d")
}
// Out:
// ID:   1 | Name: Toxic Knights of Destruction                  | MediaType ID:  3 | Genre ID:  2
// ID:   2 | Name: Atomic Prophets of Destruction                | MediaType ID:  3 | Genre ID: 14
// ID:   3 | Name: Sacred Pirates from Hell                      | MediaType ID:  4 | Genre ID: 20
// ID:   4 | Name: Savage Pirates from the Desert                | MediaType ID:  4 | Genre ID:  5
// ID:   5 | Name: Digital Zombies of Destruction                | MediaType ID:  1 | Genre ID:  9
// ID:   6 | Name: Velvet Echo of Tomorrow                       | MediaType ID:  2 | Genre ID: 17
// ID:   7 | Name: Sacred Angels from Beyond                     | MediaType ID:  1 | Genre ID: 23
// ID:   8 | Name: Golden Lions of Destruction                   | MediaType ID:  3 | Genre ID: 18
// ID:   9 | Name: Velvet Machines from the Sky                  | MediaType ID:  1 | Genre ID: 12
// ID:  10 | Name: Cosmic Dragons of the Deep                    | MediaType ID:  4 | Genre ID:  7
// ID:  11 | Name: Crimson Machines of Doom                      | MediaType ID:  2 | Genre ID: 11
// ID:  12 | Name: Electric Saints of the Abyss                  | MediaType ID:  5 | Genre ID: 12
// ID:  13 | Name: Wild Wolves in Shadow                         | MediaType ID:  3 | Genre ID: 11
// ID:  14 | Name: Velvet Thunder of Death                       | MediaType ID:  2 | Genre ID:  9
// ID:  15 | Name: Toxic Ghosts of the Abyss                     | MediaType ID:  1 | Genre ID:  5
// ID:  16 | Name: Wild Heroes from the Sky                      | MediaType ID:  4 | Genre ID:  8
// ID:  17 | Name: Eternal Thunder of Eternity                   | MediaType ID:  2 | Genre ID: 19
// ID:  18 | Name: Cosmic Machines of Eternity                   | MediaType ID:  2 | Genre ID:  5
// ID:  19 | Name: Sonic Warriors from Hell                      | MediaType ID:  3 | Genre ID: 21
// ID:  20 | Name: Savage Machines of Doom                       | MediaType ID:  5 | Genre ID: 25
// ID:  21 | Name: Cosmic Dragons from the East                  | MediaType ID:  1 | Genre ID: 23
// ID:  22 | Name: Mystic Machines from Mars                     | MediaType ID:  3 | Genre ID:  8
// ID:  23 | Name: Mystic Rebels in Chains                       | MediaType ID:  4 | Genre ID: 16
// ID:  24 | Name: Cosmic Warriors from the Desert               | MediaType ID:  1 | Genre ID:  5
// ID:  25 | Name: Primal Prophets of Tomorrow                   | MediaType ID:  2 | Genre ID: 11
// ID:  26 | Name: Velvet Pirates from Beyond                    | MediaType ID:  5 | Genre ID:  6
// ID:  27 | Name: Arctic Ghosts from Beyond                     | MediaType ID:  2 | Genre ID:  8
// ID:  28 | Name: Raging Heroes in Shadow                       | MediaType ID:  2 | Genre ID:  6
// ID:  29 | Name: Golden Killers of the Night                   | MediaType ID:  1 | Genre ID:  3
// ID:  30 | Name: Royal Outlaws from the Desert                 | MediaType ID:  2 | Genre ID: 12
// ID:  31 | Name: Midnight Heroes in Shadow                     | MediaType ID:  3 | Genre ID: 11
// ID:  32 | Name: Midnight Heroes of Tomorrow                   | MediaType ID:  4 | Genre ID: 23
// ID:  33 | Name: Phantom Heroes of the Night                   | MediaType ID:  3 | Genre ID: 12
// ID:  34 | Name: Crimson Prophets of Doom                      | MediaType ID:  4 | Genre ID:  6
// ID:  35 | Name: Royal Kings of the Night                      | MediaType ID:  3 | Genre ID: 13
// ID:  36 | Name: Phantom Wizards of Eternity                   | MediaType ID:  5 | Genre ID:  3
// ID:  37 | Name: Neon Dragons in Disguise                      | MediaType ID:  2 | Genre ID:  4
// ID:  38 | Name: Eternal Empire from the Sky                   | MediaType ID:  5 | Genre ID: 23
// ID:  39 | Name: Silent Zombies of the Abyss                   | MediaType ID:  2 | Genre ID: 11
// ID:  40 | Name: Stellar Kings from Beyond                     | MediaType ID:  1 | Genre ID:  9
// ID:  41 | Name: Cosmic Knights from Beyond                    | MediaType ID:  2 | Genre ID: 24
// ID:  42 | Name: Golden Knights of Tomorrow                    | MediaType ID:  2 | Genre ID: 10
// ID:  43 | Name: Stellar Pirates from Hell                     | MediaType ID:  2 | Genre ID:  2
// ID:  44 | Name: Cosmic Pirates of Doom                        | MediaType ID:  4 | Genre ID: 19
// ID:  45 | Name: Sacred Horizon from Beyond                    | MediaType ID:  5 | Genre ID: 11
// ID:  46 | Name: Savage Heroes in Exile                        | MediaType ID:  1 | Genre ID: 24
// ID:  47 | Name: Crystal Rebels of the Underground             | MediaType ID:  4 | Genre ID:  1
// ID:  48 | Name: Neon Heroes of Tomorrow                       | MediaType ID:  3 | Genre ID: 25
// ID:  49 | Name: Sacred Warriors of the Underground            | MediaType ID:  5 | Genre ID: 11
// ID:  50 | Name: Urban Angels from the East                    | MediaType ID:  2 | Genre ID: 13
// ID:  51 | Name: Atomic Zombies in Flames                      | MediaType ID:  5 | Genre ID:  1
// ID:  52 | Name: Lunar Horizon in Shadow                       | MediaType ID:  4 | Genre ID: 20
// ID:  53 | Name: Arctic Demons from Beyond                     | MediaType ID:  3 | Genre ID: 25
// ID:  54 | Name: Digital Shadows in Flames                     | MediaType ID:  3 | Genre ID: 16
// ID:  55 | Name: Royal Rebels from Mars                        | MediaType ID:  1 | Genre ID:  9
// ID:  56 | Name: Crystal Warriors of Tomorrow                  | MediaType ID:  5 | Genre ID:  8
// ID:  57 | Name: Golden Warriors of Tomorrow                   | MediaType ID:  2 | Genre ID: 10
// ID:  58 | Name: Stellar Dragons in Disguise                   | MediaType ID:  4 | Genre ID:  3
// ID:  59 | Name: Urban Prophets in Disguise                    | MediaType ID:  1 | Genre ID: 15
// ID:  60 | Name: Crystal Echo from Beyond                      | MediaType ID:  1 | Genre ID: 18
// ID:  61 | Name: Stellar Rebels in Flames                      | MediaType ID:  1 | Genre ID:  6
// ID:  62 | Name: Savage Empire from the Desert                 | MediaType ID:  1 | Genre ID:  4
// ID:  63 | Name: Savage Lions of the Deep                      | MediaType ID:  3 | Genre ID: 17
// ID:  64 | Name: Savage Angels from Hell                       | MediaType ID:  2 | Genre ID:  8
// ID:  65 | Name: Screaming Rebels of Doom                      | MediaType ID:  1 | Genre ID: 17
// ID:  66 | Name: Silent Knights from Mars                      | MediaType ID:  1 | Genre ID:  4
// ID:  67 | Name: Crystal Zombies from Hell                     | MediaType ID:  1 | Genre ID:  2
// ID:  68 | Name: Toxic Wolves in Exile                         | MediaType ID:  3 | Genre ID: 20
// ID:  69 | Name: Urban Rebels of Destruction                   | MediaType ID:  2 | Genre ID:  2
// ID:  70 | Name: Raging Giants of Tomorrow                     | MediaType ID:  3 | Genre ID:  6
// ID:  71 | Name: Silent Titans in Exile                        | MediaType ID:  3 | Genre ID: 16
// ID:  72 | Name: Digital Thunder from Beyond                   | MediaType ID:  2 | Genre ID:  7
// ID:  73 | Name: Wild Kings from Hell                          | MediaType ID:  4 | Genre ID:  6
// ID:  74 | Name: Mystic Angels in Flames                       | MediaType ID:  3 | Genre ID: 24
// ID:  75 | Name: Midnight Kings of the North                   | MediaType ID:  4 | Genre ID: 18
// ID:  76 | Name: Silent Killers in Shadow                      | MediaType ID:  1 | Genre ID: 24
// ID:  77 | Name: Velvet Ghosts in Chains                       | MediaType ID:  2 | Genre ID:  6
// ID:  78 | Name: Sonic Angels in Flames                        | MediaType ID:  4 | Genre ID: 21
// ID:  79 | Name: Crystal Titans of Eternity                    | MediaType ID:  5 | Genre ID: 20
// ID:  80 | Name: Electric Ravens of Tomorrow                   | MediaType ID:  1 | Genre ID: 19
// ID:  81 | Name: Atomic Wolves of the Deep                     | MediaType ID:  3 | Genre ID:  5
// ID:  82 | Name: Eternal Prophets of the Deep                  | MediaType ID:  1 | Genre ID: 12
// ID:  83 | Name: Stellar Empire from the East                  | MediaType ID:  4 | Genre ID: 10
// ID:  84 | Name: Phantom Killers of Eternity                   | MediaType ID:  5 | Genre ID: 21
// ID:  85 | Name: Silent Outlaws of Eternity                    | MediaType ID:  1 | Genre ID: 16
// ID:  86 | Name: Screaming Heroes in Shadow                    | MediaType ID:  5 | Genre ID: 22
// ID:  87 | Name: Screaming Thunder from Mars                   | MediaType ID:  5 | Genre ID: 18
// ID:  88 | Name: Silent Titans of Tomorrow                     | MediaType ID:  1 | Genre ID:  7
// ID:  89 | Name: Phantom Demons from the Sky                   | MediaType ID:  2 | Genre ID:  3
// ID:  90 | Name: Eternal Warriors in Shadow                    | MediaType ID:  4 | Genre ID:  2
// ID:  91 | Name: Screaming Zombies of the North                | MediaType ID:  2 | Genre ID:  3
// ID:  92 | Name: Stellar Wolves of Death                       | MediaType ID:  5 | Genre ID: 21
// ID:  93 | Name: Velvet Rebels from the East                   | MediaType ID:  4 | Genre ID: 11
// ID:  94 | Name: Atomic Outlaws in Shadow                      | MediaType ID:  3 | Genre ID: 10
// ID:  95 | Name: Neon Void from Hell                           | MediaType ID:  2 | Genre ID: 13
// ID:  96 | Name: Toxic Thunder of Doom                         | MediaType ID:  2 | Genre ID: 11
// ID:  97 | Name: Savage Ghosts of the Underground              | MediaType ID:  1 | Genre ID:  5
// ID:  98 | Name: Phantom Giants in Chains                      | MediaType ID:  3 | Genre ID: 18
// ID:  99 | Name: Wild Wolves in Flames                         | MediaType ID:  3 | Genre ID: 19
// ID: 100 | Name: Golden Prophets from Beyond                   | MediaType ID:  2 | Genre ID:  1
// ID: 101 | Name: Silent Ghosts in Disguise                     | MediaType ID:  3 | Genre ID:  8
// ID: 102 | Name: Electric Bandits of Tomorrow                  | MediaType ID:  5 | Genre ID:  8
// ID: 103 | Name: Eternal Killers in Disguise                   | MediaType ID:  1 | Genre ID: 13
// ID: 104 | Name: Atomic Lions from the Desert                  | MediaType ID:  5 | Genre ID:  3
// ID: 105 | Name: Crystal Giants of the Deep                    | MediaType ID:  1 | Genre ID: 25
// ID: 106 | Name: Screaming Knights from the Desert             | MediaType ID:  2 | Genre ID: 22
// ID: 107 | Name: Liquid Wolves of Destruction                  | MediaType ID:  4 | Genre ID: 13
// ID: 108 | Name: Lunar Giants of Doom                          | MediaType ID:  4 | Genre ID: 12
// ID: 109 | Name: Primal Heroes of the Abyss                    | MediaType ID:  5 | Genre ID:  4
// ID: 110 | Name: Infinite Dragons of Tomorrow                  | MediaType ID:  5 | Genre ID:  4
// ID: 111 | Name: Mystic Heroes in Disguise                     | MediaType ID:  1 | Genre ID: 24
// ID: 112 | Name: Sonic Lions from the Desert                   | MediaType ID:  1 | Genre ID: 14
// ID: 113 | Name: Primal Rebels of the Abyss                    | MediaType ID:  3 | Genre ID:  3
// ID: 114 | Name: Eternal Titans from Beyond                    | MediaType ID:  5 | Genre ID: 16
// ID: 115 | Name: Liquid Wolves of the Abyss                    | MediaType ID:  4 | Genre ID: 22
// ID: 116 | Name: Crystal Wizards in Disguise                   | MediaType ID:  1 | Genre ID: 20
// ID: 117 | Name: Cosmic Outlaws from Beyond                    | MediaType ID:  5 | Genre ID: 19
// ID: 118 | Name: Digital Knights of Death                      | MediaType ID:  5 | Genre ID: 14
// ID: 119 | Name: Royal Warriors of Tomorrow                    | MediaType ID:  4 | Genre ID: 25
// ID: 120 | Name: Arctic Void of the Abyss                      | MediaType ID:  1 | Genre ID: 17
// ID: 121 | Name: Eternal Prophets of the North                 | MediaType ID:  2 | Genre ID: 23
// ID: 122 | Name: Digital Heroes in Disguise                    | MediaType ID:  1 | Genre ID: 24
// ID: 123 | Name: Velvet Thunder of Death                       | MediaType ID:  3 | Genre ID: 20
// ID: 124 | Name: Lost Machines from Hell                       | MediaType ID:  2 | Genre ID: 16
// ID: 125 | Name: Sacred Wolves from Hell                       | MediaType ID:  2 | Genre ID: 17
// ID: 126 | Name: Eternal Lions of Tomorrow                     | MediaType ID:  5 | Genre ID: 21
// ID: 127 | Name: Screaming Echo in Exile                       | MediaType ID:  2 | Genre ID: 18
// ID: 128 | Name: Infinite Horizon from Mars                    | MediaType ID:  4 | Genre ID:  1
// ID: 129 | Name: Urban Wizards in Flames                       | MediaType ID:  3 | Genre ID: 11
// ID: 130 | Name: Electric Knights in Shadow                    | MediaType ID:  4 | Genre ID:  8
// ID: 131 | Name: Neon Zombies from the East                    | MediaType ID:  4 | Genre ID:  5
// ID: 132 | Name: Lost Void of Doom                             | MediaType ID:  5 | Genre ID:  6
// ID: 133 | Name: Crimson Warriors from the Desert              | MediaType ID:  3 | Genre ID: 19
// ID: 134 | Name: Phantom Machines of the Underground           | MediaType ID:  2 | Genre ID:  7
// ID: 135 | Name: Electric Ghosts of Doom                       | MediaType ID:  2 | Genre ID: 21
// ID: 136 | Name: Neon Wizards of the Abyss                     | MediaType ID:  4 | Genre ID: 23
// ID: 137 | Name: Electric Horizon of the Night                 | MediaType ID:  2 | Genre ID:  8
// ID: 138 | Name: Toxic Shadows of the Night                    | MediaType ID:  3 | Genre ID: 23
// ID: 139 | Name: Midnight Angels from Hell                     | MediaType ID:  5 | Genre ID:  2
// ID: 140 | Name: Sonic Machines from the Sky                   | MediaType ID:  2 | Genre ID:  1
// ID: 141 | Name: Electric Rebels of Death                      | MediaType ID:  1 | Genre ID: 15
// ID: 142 | Name: Toxic Kings from Hell                         | MediaType ID:  3 | Genre ID: 21
// ID: 143 | Name: Midnight Heroes in Exile                      | MediaType ID:  3 | Genre ID: 22
// ID: 144 | Name: Royal Bandits in Flames                       | MediaType ID:  4 | Genre ID: 23
// ID: 145 | Name: Midnight Titans in Chains                     | MediaType ID:  1 | Genre ID:  3
// ID: 146 | Name: Toxic Thunder of the Abyss                    | MediaType ID:  3 | Genre ID: 16
// ID: 147 | Name: Toxic Killers from the East                   | MediaType ID:  1 | Genre ID:  5
// ID: 148 | Name: Urban Shadows in Disguise                     | MediaType ID:  1 | Genre ID: 15
// ID: 149 | Name: Liquid Demons from the Sky                    | MediaType ID:  3 | Genre ID:  6
// ID: 150 | Name: Crimson Giants from Mars                      | MediaType ID:  2 | Genre ID: 10
// ID: 151 | Name: Atomic Kings of the Night                     | MediaType ID:  3 | Genre ID:  9
// ID: 152 | Name: Crystal Ravens of the Deep                    | MediaType ID:  1 | Genre ID:  6
// ID: 153 | Name: Crystal Empire from the Desert                | MediaType ID:  3 | Genre ID:  5
// ID: 154 | Name: Royal Rebels in Flames                        | MediaType ID:  5 | Genre ID: 24
// ID: 155 | Name: Royal Zombies from the Desert                 | MediaType ID:  3 | Genre ID: 24
// ID: 156 | Name: Stellar Shadows in Exile                      | MediaType ID:  2 | Genre ID:  1
// ID: 157 | Name: Electric Ghosts of the Night                  | MediaType ID:  5 | Genre ID: 10
// ID: 158 | Name: Eternal Saints from Beyond                    | MediaType ID:  1 | Genre ID: 25
// ID: 159 | Name: Eternal Void of the Deep                      | MediaType ID:  4 | Genre ID: 11
// ID: 160 | Name: Raging Pirates of Doom                        | MediaType ID:  5 | Genre ID:  9
// ID: 161 | Name: Silent Warriors of the North                  | MediaType ID:  3 | Genre ID: 23
// ID: 162 | Name: Screaming Knights from Mars                   | MediaType ID:  5 | Genre ID: 13
// ID: 163 | Name: Crimson Echo from Hell                        | MediaType ID:  3 | Genre ID: 12
// ID: 164 | Name: Liquid Dragons in Exile                       | MediaType ID:  5 | Genre ID: 17
// ID: 165 | Name: Stellar Zombies of the Underground            | MediaType ID:  3 | Genre ID: 15
// ID: 166 | Name: Screaming Killers from the Desert             | MediaType ID:  4 | Genre ID: 14
// ID: 167 | Name: Screaming Dragons in Disguise                 | MediaType ID:  3 | Genre ID: 19
// ID: 168 | Name: Silent Kings of the North                     | MediaType ID:  2 | Genre ID: 19
// ID: 169 | Name: Digital Shadows of Doom                       | MediaType ID:  4 | Genre ID:  1
// ID: 170 | Name: Screaming Pirates of Tomorrow                 | MediaType ID:  5 | Genre ID: 20
// ID: 171 | Name: Sonic Saints of Eternity                      | MediaType ID:  4 | Genre ID:  8
// ID: 172 | Name: Lunar Ravens from Beyond                      | MediaType ID:  4 | Genre ID:  9
// ID: 173 | Name: Wild Ravens of Doom                           | MediaType ID:  3 | Genre ID: 18
// ID: 174 | Name: Atomic Knights of Death                       | MediaType ID:  3 | Genre ID: 15
// ID: 175 | Name: Crystal Horizon in Exile                      | MediaType ID:  5 | Genre ID: 15
// ID: 176 | Name: Digital Echo of Death                         | MediaType ID:  3 | Genre ID:  7
// ID: 177 | Name: Infinite Knights of the North                 | MediaType ID:  1 | Genre ID: 23
// ID: 178 | Name: Primal Titans from the East                   | MediaType ID:  3 | Genre ID: 17
// ID: 179 | Name: Electric Rebels of the Night                  | MediaType ID:  1 | Genre ID: 24
// ID: 180 | Name: Primal Empire in Disguise                     | MediaType ID:  5 | Genre ID:  9
// ID: 181 | Name: Toxic Horizon of Destruction                  | MediaType ID:  2 | Genre ID: 16
// ID: 182 | Name: Royal Ghosts of Eternity                      | MediaType ID:  1 | Genre ID: 25
// ID: 183 | Name: Mystic Ghosts of Doom                         | MediaType ID:  2 | Genre ID: 18
// ID: 184 | Name: Lunar Killers in Disguise                     | MediaType ID:  1 | Genre ID: 16
// ID: 185 | Name: Toxic Lions from Hell                         | MediaType ID:  3 | Genre ID:  1
// ID: 186 | Name: Mystic Demons in Disguise                     | MediaType ID:  2 | Genre ID: 12
// ID: 187 | Name: Velvet Giants of Eternity                     | MediaType ID:  4 | Genre ID:  1
// ID: 188 | Name: Raging Titans of Doom                         | MediaType ID:  1 | Genre ID:  1
// ID: 189 | Name: Silent Outlaws from the Desert                | MediaType ID:  1 | Genre ID: 13
// ID: 190 | Name: Urban Ravens of the Abyss                     | MediaType ID:  5 | Genre ID: 17
// ID: 191 | Name: Infinite Titans in Disguise                   | MediaType ID:  5 | Genre ID:  1
// ID: 192 | Name: Lost Demons from the Desert                   | MediaType ID:  4 | Genre ID:  6
// ID: 193 | Name: Lunar Giants from the East                    | MediaType ID:  3 | Genre ID: 13
// ID: 194 | Name: Infinite Knights of the Night                 | MediaType ID:  3 | Genre ID:  3
// ID: 195 | Name: Primal Empire of the Deep                     | MediaType ID:  1 | Genre ID:  4
// ID: 196 | Name: Primal Knights from Mars                      | MediaType ID:  1 | Genre ID: 22
// ID: 197 | Name: Lunar Rebels of the North                     | MediaType ID:  2 | Genre ID: 16
// ID: 198 | Name: Toxic Outlaws from the East                   | MediaType ID:  5 | Genre ID:  8
// ID: 199 | Name: Screaming Demons of the Deep                  | MediaType ID:  5 | Genre ID: 23
// ID: 200 | Name: Midnight Lions from Beyond                    | MediaType ID:  2 | Genre ID: 13
// defined class Employee
// defined class MediaType
// defined class Genre
// defined class Track
// defined class InvoiceItem
// defined class Invoice
// employees = Array(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))
// mediaTypes = Array(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))
// genres = Array(Genre(1,Rock), Genre(2,Jazz), G...
// Array(Genre(1,Rock), Genre(2,Jazz), G...

// %% [markdown]
// ## étape 1 - Filtrage

// %%
val media = List(1, 2, 3) // Example media type IDs to filter by
val filteredTracks = tracks.filter(track => media.contains(track.mediaType))
// Out:
// media = List(1, 2, 3)
// filteredTracks = Array(Track(2,Song B 2,1,6), Track(3,Song E 3,3,5), Track(5,Song D 5,1,17), Track(7,Song B 7,1,15), Track(10,Song C 10,2,25), Track(12,Song A 12,2,6), Track(14,Song D 14,2,25), Track(15,Song C 15,3,12), Track(16,Song C 16,2,24), Track(19,Song D 19,1,17), Track(20,Song D 20,3,5), Track(21,Song E 21,1,14), Track(22,Song D 22,2,11), Track(26,Song C 26,2,3), Track(27,Song E 27,3,4), Track(31,Song C 31,2,6), Track(32,Song A 32,1,1), Track(35,Song B 35,2,7), Track(36,Song A 36,3,22), Track(37,Song E 37,1,6), Track(38,Song A 38,3,10), Track(39,Song A 39,2,20), Track(41,Song D 41,1,13), Track(42,Song A 42,3,22), Track(44,Song E 44,3,1), Track(47,Song E 47,2,10), Track(48,Song C 48,1,19), Track(50,Song A 50,1,8), Track(52,Song A 52,...
// Array(Track(2,Song B 2,1,6), Track(3,Song E 3,3,5), Track(5,Song D 5,1,17), Track(7,Song B 7,1,15), Track(10,Song C 10,2,25), Track(12,Song A 12,2,6), Track(14,Song D 14,2,25), Track(15,Song C 15,3,12), Track(16,Song C 16,2,24), Track(19,Song D 19,1,17), Track(20,Song D 20,3,5), Track(21,Song E 21,1,14), Track(22,Song D 22,2,11), Track(26,Song C 26,2,3), Track(27,Song E 27,3,4), Track(31,Song C 31,2,6), Track(32,Song A 32,1,1), Track(35,Song B 35,2,7), Track(36,Song A 36,3,22), Track(37,Song E 37,1,6), Track(38,Song A 38,3,10), Track(39,Song A 39,2,20), Track(41,Song D 41,1,13), Track(42,Song A 42,3,22), Track(44,Song E 44,3,1), Track(47,Song E 47,2,10), Track(48,Song C 48,1,19), Track(50,Song A 50,1,8), Track(52,Song A 52,...
