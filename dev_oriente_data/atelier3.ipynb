// %% [markdown]
// # TP2

// %%
case class Employee(
  employeeId: Int,
  lastName: String,
  firstName: String,
  title: String,
  reportsTo: Int
)

case class MediaType(
  mediaTypeId: Int,
  name: String
)

case class Genre(
  genreId: Int,
  name: String
)

case class Track(
  trackId: Int,
  name: String,
  mediaType: Int,
  genre: Int
)

case class InvoiceItem(
  invoiceLineId: Int,
  invoiceId: Int,
  trackId: Int,
  unitPrice: BigDecimal,
  quantity: Int
  )

case class Invoice(
  invoiceId: Int,
  items: List[InvoiceItem]
)

val employees = Array(
  Employee(1, "Adams", "Andrew", "General Manager", 0),
  Employee(2, "Edwards", "Nancy", "Sales Manager", 1),
  Employee(3, "Peacock", "Jane", "Sales Support Agent", 2),
  Employee(4, "Park", "Margaret", "Sales Support Agent", 2),
  Employee(5, "Johnson", "Steve", "Sales Support Agent", 2),
  Employee(6, "Mitchell", "Michael", "IT Manager", 1),
  Employee(7, "King", "Robert", "IT Staff", 6),
  Employee(8, "Callahan", "Laura", "IT Staff", 6)
)

val mediaTypes = Array(
  MediaType(1, "MPEG audio file"),
  MediaType(2, "Protected AAC audio file"),
  MediaType(3, "Protected MPEG-4 video file"),
  MediaType(4, "Purchased AAC audio file"),
  MediaType(5, "AAC audio file")
)

val genres = Array(
  Genre(1, "Rock"),
  Genre(2, "Jazz"),
  Genre(3, "Metal"),
  Genre(4, "Alternative & Punk"),
  Genre(5, "Rock And Roll"),
  Genre(6, "Blues"),
  Genre(7, "Latin"),
  Genre(8, "Reggae"),
  Genre(9, "Pop"),
  Genre(10, "Soundtrack"),
  Genre(11, "Bossa Nova"),
  Genre(12, "Easy Listening"),
  Genre(13, "Heavy Metal"),
  Genre(14, "R&B/Soul"),
  Genre(15, "Electronica/Dance"),
  Genre(16, "World"),
  Genre(17, "Hip Hop/Rap"),
  Genre(18, "Science Fiction"),
  Genre(19, "TV Shows"),
  Genre(20, "Sci Fi & Fantasy"),
  Genre(21, "Drama"),
  Genre(22, "Comedy"),
  Genre(23, "Alternative"),
  Genre(24, "Classical"),
  Genre(25, "Opera")
)

val adjectives = Array("Cosmic", "Electric", "Velvet", "Mystic", "Atomic", "Phantom", "Silent", "Savage", "Eternal", "Digital", "Lost", "Sacred", "Wild", "Urban", "Golden", "Crystal", "Liquid", "Toxic", "Neon", "Crimson", "Stellar", "Raging", "Arctic", "Sonic", "Primal", "Midnight", "Screaming", "Infinite", "Royal", "Lunar")
val nouns = Array("Echo", "Giants", "Wolves", "Horizon", "Empire", "Void", "Thunder", "Dragons", "Saints", "Kings", "Ghosts", "Ravens", "Pirates", "Heroes", "Rebels", "Demons", "Machines", "Angels", "Knights", "Lions", "Shadows", "Zombies", "Wizards", "Killers", "Titans", "Outlaws", "Rebels", "Prophets", "Bandits", "Warriors")
val complements = Array("of Doom", "in Chains", "from Mars", "of the North", "of Death", "in Disguise", "of the Night", "from Hell", "of Tomorrow", "in Flames", "of the Deep", "from Beyond", "of Destruction", "in Shadow", "from the Sky", "of the Abyss", "in Exile", "from the East", "of Eternity", "from the Desert", "of the Underground")

import scala.util.Random

object Track {
  def generateTrack(trackId: Int): Track = {
    val genre = genres(Random.nextInt(genres.length)).genreId
    val mediaType = mediaTypes(Random.nextInt(mediaTypes.length)).mediaTypeId
    val name = s"${adjectives(Random.nextInt(adjectives.length))} ${nouns(Random.nextInt(nouns.length))} ${complements(Random.nextInt(complements.length))}"
    Track(trackId, name, mediaType, genre)
  }
}


object Invoice {
  def generateInvoice(invoiceId: Int, availableTracks: Array[Track]): Invoice = {
    val itemCount = Random.nextInt(5) + 1
    val selectedTracks = Random.shuffle(availableTracks.toList).take(itemCount)

    val items = selectedTracks.zipWithIndex.map { case (track, idx) =>
      val quantity = if (Random.nextDouble() < 0.8) 1 else Random.nextInt(3) + 1
      val unitPrice = BigDecimal(0.99 + Random.nextDouble() * 1.01).setScale(2, BigDecimal.RoundingMode.HALF_UP)
      InvoiceItem(
        invoiceLineId = invoiceId * 10 + idx + 1,
        invoiceId = invoiceId,
        trackId = track.trackId,
        unitPrice = unitPrice,
        quantity = quantity
      )
    }
    Invoice(invoiceId, items)
  }
}

val tracks = (1 to 200).map(Track.generateTrack).toArray
val invoices = (1 to 2000).map(id => Invoice.generateInvoice(id, tracks)).toArray

tracks.foreach { track =>
  println(f"ID: ${track.trackId}%3d | Name: ${track.name}%-45s | MediaType ID: ${track.mediaType}%2d | Genre ID: ${track.genre}%2d")
}
// Out:
// ID:   1 | Name: Phantom Saints of the Underground             | MediaType ID:  3 | Genre ID: 22
// ID:   2 | Name: Neon Thunder in Disguise                      | MediaType ID:  3 | Genre ID:  2
// ID:   3 | Name: Cosmic Heroes in Disguise                     | MediaType ID:  5 | Genre ID: 15
// ID:   4 | Name: Toxic Bandits from Hell                       | MediaType ID:  3 | Genre ID: 25
// ID:   5 | Name: Eternal Titans of Tomorrow                    | MediaType ID:  5 | Genre ID: 14
// ID:   6 | Name: Crystal Echo of Tomorrow                      | MediaType ID:  2 | Genre ID: 17
// ID:   7 | Name: Velvet Saints in Disguise                     | MediaType ID:  3 | Genre ID: 25
// ID:   8 | Name: Cosmic Pirates in Chains                      | MediaType ID:  3 | Genre ID: 19
// ID:   9 | Name: Neon Heroes in Flames                         | MediaType ID:  3 | Genre ID: 10
// ID:  10 | Name: Screaming Empire of the Underground           | MediaType ID:  3 | Genre ID: 22
// ID:  11 | Name: Phantom Killers from the Sky                  | MediaType ID:  3 | Genre ID: 15
// ID:  12 | Name: Midnight Empire in Disguise                   | MediaType ID:  5 | Genre ID: 22
// ID:  13 | Name: Neon Empire of the Night                      | MediaType ID:  3 | Genre ID:  3
// ID:  14 | Name: Lost Heroes of the North                      | MediaType ID:  5 | Genre ID: 17
// ID:  15 | Name: Toxic Void of Destruction                     | MediaType ID:  5 | Genre ID:  2
// ID:  16 | Name: Sonic Rebels of Eternity                      | MediaType ID:  5 | Genre ID:  6
// ID:  17 | Name: Royal Wizards of Destruction                  | MediaType ID:  1 | Genre ID: 10
// ID:  18 | Name: Crimson Lions of Doom                         | MediaType ID:  3 | Genre ID: 25
// ID:  19 | Name: Arctic Kings from Hell                        | MediaType ID:  3 | Genre ID: 10
// ID:  20 | Name: Cosmic Pirates in Chains                      | MediaType ID:  3 | Genre ID: 11
// ID:  21 | Name: Digital Bandits in Disguise                   | MediaType ID:  5 | Genre ID: 13
// ID:  22 | Name: Phantom Bandits from Hell                     | MediaType ID:  2 | Genre ID:  4
// ID:  23 | Name: Lost Prophets from the East                   | MediaType ID:  1 | Genre ID: 25
// ID:  24 | Name: Eternal Kings of the Abyss                    | MediaType ID:  5 | Genre ID:  7
// ID:  25 | Name: Liquid Bandits in Chains                      | MediaType ID:  4 | Genre ID: 13
// ID:  26 | Name: Toxic Zombies in Chains                       | MediaType ID:  1 | Genre ID:  9
// ID:  27 | Name: Infinite Bandits of Eternity                  | MediaType ID:  2 | Genre ID: 22
// ID:  28 | Name: Mystic Angels of Death                        | MediaType ID:  4 | Genre ID: 21
// ID:  29 | Name: Sonic Heroes of Death                         | MediaType ID:  3 | Genre ID:  2
// ID:  30 | Name: Stellar Killers of the Abyss                  | MediaType ID:  4 | Genre ID: 25
// ID:  31 | Name: Lunar Horizon in Exile                        | MediaType ID:  1 | Genre ID: 22
// ID:  32 | Name: Infinite Echo from the Sky                    | MediaType ID:  5 | Genre ID: 11
// ID:  33 | Name: Eternal Giants of the North                   | MediaType ID:  3 | Genre ID:  6
// ID:  34 | Name: Eternal Empire from the East                  | MediaType ID:  1 | Genre ID: 13
// ID:  35 | Name: Arctic Ghosts of the Deep                     | MediaType ID:  5 | Genre ID: 21
// ID:  36 | Name: Infinite Pirates in Shadow                    | MediaType ID:  1 | Genre ID: 11
// ID:  37 | Name: Sonic Empire of Eternity                      | MediaType ID:  3 | Genre ID:  6
// ID:  38 | Name: Digital Bandits of Doom                       | MediaType ID:  2 | Genre ID: 18
// ID:  39 | Name: Infinite Wolves of the Underground            | MediaType ID:  5 | Genre ID:  9
// ID:  40 | Name: Silent Void in Disguise                       | MediaType ID:  3 | Genre ID:  2
// ID:  41 | Name: Silent Outlaws of Death                       | MediaType ID:  1 | Genre ID:  4
// ID:  42 | Name: Lunar Dragons from the Sky                    | MediaType ID:  1 | Genre ID: 13
// ID:  43 | Name: Electric Dragons from the Desert              | MediaType ID:  3 | Genre ID:  5
// ID:  44 | Name: Sonic Echo of Eternity                        | MediaType ID:  2 | Genre ID:  5
// ID:  45 | Name: Mystic Bandits of Destruction                 | MediaType ID:  4 | Genre ID: 24
// ID:  46 | Name: Raging Ravens of the Underground              | MediaType ID:  5 | Genre ID: 10
// ID:  47 | Name: Neon Knights of Doom                          | MediaType ID:  1 | Genre ID: 15
// ID:  48 | Name: Urban Saints of Destruction                   | MediaType ID:  3 | Genre ID: 15
// ID:  49 | Name: Sacred Dragons of Tomorrow                    | MediaType ID:  5 | Genre ID: 18
// ID:  50 | Name: Crystal Rebels of the Night                   | MediaType ID:  1 | Genre ID:  1
// ID:  51 | Name: Liquid Pirates of Eternity                    | MediaType ID:  5 | Genre ID: 18
// ID:  52 | Name: Screaming Pirates of the Abyss                | MediaType ID:  3 | Genre ID: 12
// ID:  53 | Name: Eternal Ravens in Disguise                    | MediaType ID:  4 | Genre ID:  8
// ID:  54 | Name: Sacred Ravens of the Abyss                    | MediaType ID:  2 | Genre ID: 21
// ID:  55 | Name: Stellar Prophets from Mars                    | MediaType ID:  5 | Genre ID: 21
// ID:  56 | Name: Sacred Dragons of Death                       | MediaType ID:  4 | Genre ID: 20
// ID:  57 | Name: Liquid Zombies of the Night                   | MediaType ID:  4 | Genre ID:  8
// ID:  58 | Name: Primal Zombies of Death                       | MediaType ID:  2 | Genre ID: 14
// ID:  59 | Name: Mystic Echo in Shadow                         | MediaType ID:  3 | Genre ID:  9
// ID:  60 | Name: Screaming Prophets in Flames                  | MediaType ID:  1 | Genre ID: 24
// ID:  61 | Name: Phantom Saints of Doom                        | MediaType ID:  5 | Genre ID:  2
// ID:  62 | Name: Arctic Saints from Hell                       | MediaType ID:  4 | Genre ID: 24
// ID:  63 | Name: Lunar Zombies from Beyond                     | MediaType ID:  2 | Genre ID: 13
// ID:  64 | Name: Royal Ravens of Death                         | MediaType ID:  2 | Genre ID: 17
// ID:  65 | Name: Stellar Outlaws of Doom                       | MediaType ID:  1 | Genre ID:  5
// ID:  66 | Name: Infinite Shadows of Doom                      | MediaType ID:  4 | Genre ID: 17
// ID:  67 | Name: Cosmic Giants of Doom                         | MediaType ID:  4 | Genre ID: 12
// ID:  68 | Name: Primal Wolves from Beyond                     | MediaType ID:  4 | Genre ID: 24
// ID:  69 | Name: Toxic Angels of Tomorrow                      | MediaType ID:  3 | Genre ID: 25
// ID:  70 | Name: Raging Wolves of the Underground              | MediaType ID:  3 | Genre ID: 23
// ID:  71 | Name: Cosmic Empire of Death                        | MediaType ID:  5 | Genre ID: 20
// ID:  72 | Name: Phantom Bandits of Death                      | MediaType ID:  3 | Genre ID: 19
// ID:  73 | Name: Infinite Wolves of the Night                  | MediaType ID:  5 | Genre ID:  7
// ID:  74 | Name: Golden Shadows of the Night                   | MediaType ID:  3 | Genre ID:  9
// ID:  75 | Name: Stellar Pirates of Destruction                | MediaType ID:  2 | Genre ID:  2
// ID:  76 | Name: Lunar Dragons of the Deep                     | MediaType ID:  2 | Genre ID: 20
// ID:  77 | Name: Toxic Prophets in Disguise                    | MediaType ID:  3 | Genre ID:  2
// ID:  78 | Name: Arctic Outlaws from the Sky                   | MediaType ID:  1 | Genre ID:  8
// ID:  79 | Name: Midnight Empire from the Sky                  | MediaType ID:  4 | Genre ID: 18
// ID:  80 | Name: Crystal Knights of Destruction                | MediaType ID:  1 | Genre ID: 13
// ID:  81 | Name: Screaming Ravens in Chains                    | MediaType ID:  3 | Genre ID: 16
// ID:  82 | Name: Primal Heroes from Beyond                     | MediaType ID:  5 | Genre ID: 22
// ID:  83 | Name: Electric Prophets in Flames                   | MediaType ID:  2 | Genre ID:  9
// ID:  84 | Name: Arctic Empire from the Sky                    | MediaType ID:  1 | Genre ID: 15
// ID:  85 | Name: Lost Zombies of the Underground               | MediaType ID:  4 | Genre ID: 16
// ID:  86 | Name: Raging Knights of Tomorrow                    | MediaType ID:  5 | Genre ID: 16
// ID:  87 | Name: Midnight Wolves in Exile                      | MediaType ID:  4 | Genre ID:  1
// ID:  88 | Name: Urban Prophets of Doom                        | MediaType ID:  5 | Genre ID: 13
// ID:  89 | Name: Stellar Killers in Disguise                   | MediaType ID:  1 | Genre ID: 17
// ID:  90 | Name: Urban Wizards of the Night                    | MediaType ID:  1 | Genre ID: 21
// ID:  91 | Name: Electric Demons of the North                  | MediaType ID:  5 | Genre ID:  3
// ID:  92 | Name: Atomic Machines in Exile                      | MediaType ID:  1 | Genre ID:  3
// ID:  93 | Name: Wild Zombies of Destruction                   | MediaType ID:  2 | Genre ID: 16
// ID:  94 | Name: Silent Titans of Doom                         | MediaType ID:  3 | Genre ID: 22
// ID:  95 | Name: Lunar Void of the Abyss                       | MediaType ID:  5 | Genre ID: 22
// ID:  96 | Name: Golden Echo in Shadow                         | MediaType ID:  1 | Genre ID: 13
// ID:  97 | Name: Eternal Ravens from the Sky                   | MediaType ID:  2 | Genre ID: 22
// ID:  98 | Name: Liquid Saints in Flames                       | MediaType ID:  2 | Genre ID:  1
// ID:  99 | Name: Sacred Rebels from the Desert                 | MediaType ID:  3 | Genre ID: 16
// ID: 100 | Name: Crystal Killers in Exile                      | MediaType ID:  4 | Genre ID: 20
// ID: 101 | Name: Midnight Void in Flames                       | MediaType ID:  2 | Genre ID: 14
// ID: 102 | Name: Digital Giants of the Underground             | MediaType ID:  5 | Genre ID:  2
// ID: 103 | Name: Phantom Killers in Chains                     | MediaType ID:  4 | Genre ID: 12
// ID: 104 | Name: Urban Ghosts of the Night                     | MediaType ID:  5 | Genre ID:  8
// ID: 105 | Name: Infinite Heroes in Shadow                     | MediaType ID:  4 | Genre ID: 19
// ID: 106 | Name: Lost Prophets of the Deep                     | MediaType ID:  2 | Genre ID:  2
// ID: 107 | Name: Sonic Zombies of the Deep                     | MediaType ID:  5 | Genre ID: 22
// ID: 108 | Name: Midnight Bandits of Death                     | MediaType ID:  4 | Genre ID: 16
// ID: 109 | Name: Raging Ravens of the Underground              | MediaType ID:  1 | Genre ID: 17
// ID: 110 | Name: Wild Rebels of the Abyss                      | MediaType ID:  3 | Genre ID: 23
// ID: 111 | Name: Wild Empire from the East                     | MediaType ID:  1 | Genre ID:  3
// ID: 112 | Name: Crimson Empire of Destruction                 | MediaType ID:  2 | Genre ID: 13
// ID: 113 | Name: Phantom Angels of Death                       | MediaType ID:  3 | Genre ID: 18
// ID: 114 | Name: Crimson Wolves of the North                   | MediaType ID:  1 | Genre ID: 17
// ID: 115 | Name: Sacred Shadows of Destruction                 | MediaType ID:  4 | Genre ID: 24
// ID: 116 | Name: Raging Prophets of Death                      | MediaType ID:  1 | Genre ID: 12
// ID: 117 | Name: Wild Thunder of the Abyss                     | MediaType ID:  4 | Genre ID: 10
// ID: 118 | Name: Primal Prophets of Destruction                | MediaType ID:  4 | Genre ID:  2
// ID: 119 | Name: Cosmic Giants of Tomorrow                     | MediaType ID:  4 | Genre ID:  8
// ID: 120 | Name: Sonic Shadows of Doom                         | MediaType ID:  5 | Genre ID: 14
// ID: 121 | Name: Eternal Warriors in Shadow                    | MediaType ID:  5 | Genre ID: 19
// ID: 190 | Name: Urban Killers from Beyond                     | MediaType ID:  4 | Genre ID:  4
// ID: 191 | Name: Wild Titans in Exile                          | MediaType ID:  1 | Genre ID: 23
// ID: 192 | Name: Atomic Bandits of Doom                        | MediaType ID:  2 | Genre ID:  4
// ID: 193 | Name: Golden Heroes in Flames                       | MediaType ID:  5 | Genre ID:  5
// ID: 194 | Name: Electric Dragons of Tomorrow                  | MediaType ID:  3 | Genre ID:  3
// ID: 195 | Name: Screaming Killers of the Deep                 | MediaType ID:  3 | Genre ID:  2
// ID: 196 | Name: Crimson Ghosts in Chains                      | MediaType ID:  5 | Genre ID: 18
// ID: 197 | Name: Phantom Warriors of the Deep                  | MediaType ID:  2 | Genre ID: 16
// ID: 198 | Name: Velvet Killers from Hell                      | MediaType ID:  1 | Genre ID: 17
// ID: 199 | Name: Sacred Demons of Destruction                  | MediaType ID:  2 | Genre ID:  1
// ID: 200 | Name: Arctic Kings of Death                         | MediaType ID:  2 | Genre ID: 21
// defined class Employee
// defined class MediaType
// defined class Genre
// defined class Track
// defined class InvoiceItem
// defined class Invoice
// employees = Array(Employee(1,Adams,Andrew,General Manager,0), Employee(2,Edwards,Nancy,Sales Manager,1), Employee(3,Peacock,Jane,Sales Support Agent,2), Employee(4,Park,Margaret,Sales Support Agent,2), Employee(5,Johnson,Steve,Sales Support Agent,2), Employee(6,Mitchell,Michael,IT Manager,1), Employee(7,King,Robert,IT Staff,6), Employee(8,Callahan,Laura,IT Staff,6))
// mediaTypes = Array(MediaType(1,MPEG audio file), MediaType(2,Protected AAC audio file), MediaType(3,Protected MPEG-4 video file), MediaType(4,Purchased AAC audio file), MediaType(5,AAC audio file))
// genres = Array(Genre(1,Rock), Genre(2,Jazz), G...
// Array(Genre(1,Rock), Genre(2,Jazz), G...

// %% [markdown]
// ## étape 1 - Filtrage

// %%
val media = List(1, 2, 3)
val filteredTracks = tracks.filter(track => media.contains(track.mediaType))
val invoiceFiltered = invoices.filter { invoice =>
    invoice.items.forall { item =>
        tracks.find(_.trackId == item.trackId).exists(_.genre == 1)
    }
}

invoiceFiltered.foreach { invoice =>
  println(s"Invoice ID: ${invoice.invoiceId}")
  invoice.items.foreach { item =>
    println(f"  Invoice Line ID: ${item.invoiceLineId}%3d | Track ID: ${item.trackId}%3d | Prix: ${item.unitPrice}%.2f | Quantité: ${item.quantity}%2d")
  }
}
// Out:
// Invoice ID: 61
//   Invoice Line ID: 611 | Track ID:  87 | Prix: 1.62 | Quantité:  1
// Invoice ID: 90
//   Invoice Line ID: 901 | Track ID: 199 | Prix: 1.41 | Quantité:  1
// Invoice ID: 326
//   Invoice Line ID: 3261 | Track ID: 145 | Prix: 1.13 | Quantité:  1
// Invoice ID: 629
//   Invoice Line ID: 6291 | Track ID: 149 | Prix: 1.83 | Quantité:  1
// Invoice ID: 829
//   Invoice Line ID: 8291 | Track ID: 149 | Prix: 1.67 | Quantité:  1
// Invoice ID: 917
//   Invoice Line ID: 9171 | Track ID: 149 | Prix: 1.71 | Quantité:  1
// Invoice ID: 1054
//   Invoice Line ID: 10541 | Track ID:  87 | Prix: 1.43 | Quantité:  1
// Invoice ID: 1415
//   Invoice Line ID: 14151 | Track ID: 145 | Prix: 1.70 | Quantité:  1
// Invoice ID: 1482
//   Invoice Line ID: 14821 | Track ID: 199 | Prix: 1.82 | Quantité:  1
//   Invoice Line ID: 14822 | Track ID:  50 | Prix: 1.61 | Quantité:  3
// Invoice ID: 1525
//   Invoice Line ID: 15251 | Track ID: 149 | Prix: 1.42 | Quantité:  1
// Invoice ID: 1547
//   Invoice Line ID: 15471 | Track ID: 199 | Prix: 1.18 | Quantité:  1
// Invoice ID: 1826
//   Invoice Line ID: 18261 | Track ID: 145 | Prix: 1.43 | Quantité:  1
// Invoice ID: 1839
//   Invoice Line ID: 18391 | Track ID: 145 | Prix: 1.72 | Quantité:  1
// Invoice ID: 1976
//   Invoice Line ID: 19761 | Track ID: 145 | Prix: 1.35 | Quantité:  1
// media = List(1, 2, 3)
// filteredTracks = Array(Track(1,Phantom Saints of the Underground,3,22), Track(2,Neon Thunder in Disguise,3,2), Track(4,Toxic Bandits from Hell,3,25), Track(6,Crystal Echo of Tomorrow,2,17), Track(7,Velvet Saints in Disguise,3,25), Track(8,Cosmic Pirates in Chains,3,19), Track(9,Neon Heroes in Flames,3,10), Track(10,Screaming Empire of the Underground,3,22), Track(11,Phantom Killers from the Sky,3,15), Track(13,Neon Empire of the Night,3,3), Track(17,Royal Wizards of Destruction,1,10), Track(18,Crimson Lions of Doom,3,25), Track(19,Arctic Kings from Hell,3,10), Track(20,Cosmic Pirates in Chains,3,11), Track(22,Phantom Bandits from Hell,2,4), Track(23,Lost Prophets from the East,1,25), Track(26,Toxic Zombies in Chains,1,9), Track(27,Infinite ...
// Array(Track(1,Phantom Saints of the Underground,3,22), Track(2,Neon Thunder in Disguise,3,2), Track(4,Toxic Bandits from Hell,3,25), Track(6,Crystal Echo of Tomorrow,2,17), Track(7,Velvet Saints in Disguise,3,25), Track(8,Cosmic Pirates in Chains,3,19), Track(9,Neon Heroes in Flames,3,10), Track(10,Screaming Empire of the Underground,3,22), Track(11,Phantom Killers from the Sky,3,15), Track(13,Neon Empire of the Night,3,3), Track(17,Royal Wizards of Destruction,1,10), Track(18,Crimson Lions of Doom,3,25), Track(19,Arctic Kings from Hell,3,10), Track(20,Cosmic Pirates in Chains,3,11), Track(22,Phantom Bandits from Hell,2,4), Track(23,Lost Prophets from the East,1,25), Track(26,Toxic Zombies in Chains,1,9), Track(27,Infinite ...

// %% [markdown]
// ## Étape 2 - Agrégations

// %%
val topSales = tracks
    .map { track =>
        val totalSales = invoices.flatMap(_.items).filter(_.trackId == track.trackId).map(_.quantity).sum
        (track, totalSales)
    }
    .sortBy { case (_, sales) => -sales }
    .take(5)

println("Top 5")
topSales.foreach { case (track, sales) =>
    println(f"Track ID: ${track.trackId}%3d | Nom: ${track.name}%-45s | Total ventes: $sales")
}

val totalOrdersByGenre = genres.map { genre =>
    val trackIds = tracks.filter(_.genre == genre.genreId).map(_.trackId).toSet
    val totalOrders = invoices.flatMap(_.items).count(item => trackIds.contains(item.trackId))
    (genre.name, totalOrders)
}.toMap

println("Total commande par genre")
totalOrdersByGenre.foreach { case (genre, total) =>
    println(f"Genre: $genre%-20s | Total commande: $total")
}
// Out:
// Top 5
// Track ID:  72 | Nom: Phantom Bandits of Death                      | Total ventes: 51
// Track ID: 116 | Nom: Raging Prophets of Death                      | Total ventes: 51
// Track ID: 172 | Nom: Digital Dragons in Exile                      | Total ventes: 47
// Track ID: 185 | Nom: Screaming Heroes from the East                | Total ventes: 47
// Track ID: 198 | Nom: Velvet Killers from Hell                      | Total ventes: 47
// Total commande par genre
// Genre: R&B/Soul             | Total commande: 275
// Genre: Metal                | Total commande: 201
// Genre: Opera                | Total commande: 325
// Genre: Rock                 | Total commande: 210
// Genre: Latin                | Total commande: 151
// Genre: Classical            | Total commande: 267
// Genre: Comedy               | Total commande: 330
// Genre: Science Fiction      | Total commande: 284
// Genre: Sci Fi & Fantasy     | Total commande: 246
// Genre: Drama                | Total commande: 195
// Genre: Pop                  | Total commande: 216
// Genre: Hip Hop/Rap          | Total commande: 262
// Genre: Jazz                 | Total commande: 419
// Genre: Electronica/Dance    | Total commande: 160
// Genre: TV Shows             | Total commande: 218
// Genre: Blues                | Total commande: 162
// Genre: Heavy Metal          | Total commande: 306
// Genre: Rock And Roll        | Total commande: 210
// Genre: Soundtrack           | Total commande: 273
// Genre: Reggae               | Total commande: 269
// Genre: Easy Listening       | Total commande: 199
// Genre: Alternative          | Total commande: 80
// Genre: Alternative & Punk   | Total commande: 189
// Genre: World                | Total commande: 240
// Genre: Bossa Nova           | Total commande: 142
// topSales = Array((Track(72,Phantom Bandits of Death,3,19),51), (Track(116,Raging Prophets of Death,1,12),51), (Track(172,Digital Dragons in Exile,3,19),47), (Track(185,Screaming Heroes from the East,5,20),47), (Track(198,Velvet Killers from Hell,1,17),47))
// totalOrdersByGenre = Map(R&B/Soul -> 275, Metal -> 201, Opera -> 325, Rock -> 210, Latin -> 151, Classical -> 267, Comedy -> 330, Science Fiction -> 284, Sci Fi & Fantasy -> 246, Drama -> 195, Pop -> 216, Hip Hop/Rap -> 262, Jazz -> 419, Electronica/Dance -> 160, TV Shows -> 218, Blues -> 162, Heavy Metal -> 306, Rock And Roll -> 210, Soundtrack -> 273, Reggae -> 269, Easy Listening -> 199, Alternative -> 80, Alternative & Punk -> 189, World -> 240, Bossa Nova -> 142)
// Map(R&B/Soul -> 275, Metal -> 201, Opera -> 325, Rock -> 210, Latin -> 151, Classical -> 267, Comedy -> 330, Science Fiction -> 284, Sci Fi & Fantasy -> 246, Drama -> 195, Pop -> 216, Hip Hop/Rap -> 262, Jazz -> 419, Electronica/Dance -> 160, TV Shows -> 218, Blues -> 162, Heavy Metal -> 306, Rock And Roll -> 210, Soundtrack -> 273, Reggae -> 269, Easy Listening -> 199, Alternative -> 80, Alternative & Punk -> 189, World -> 240, Bossa Nova -> 142)

// %% [markdown]
// ## Étape 3 - Traitement récursif

// %%
def findTopManager(employeeId: Int): Employee = {
    val employee = employees.find(_.employeeId == employeeId).get
    if (employee.reportsTo == 0) employee
    else findTopManager(employee.reportsTo)
}

val emp = employees(2)
val topManager = findTopManager(emp.employeeId)
println(s"Le plus haut responsable de ${emp.firstName} ${emp.lastName} est ${topManager.firstName} ${topManager.lastName}")
// Out:
// Le plus haut responsable de Jane Peacock est Andrew Adams
// emp = Employee(3,Peacock,Jane,Sales Support Agent,2)
// topManager = Employee(1,Adams,Andrew,General Manager,0)
// findTopManager: (employeeId: Int)Employee
// Employee(1,Adams,Andrew,General Manager,0)
